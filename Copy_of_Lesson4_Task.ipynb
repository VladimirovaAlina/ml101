# %% [markdown]
# <a href="https://colab.research.google.com/github/VladimirovaAlina/ML/blob/master/Copy_of_Lesson4_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 0. Import Opencv and numpy

# %%
import numpy as np
import cv2 as cv # OpenCV library
from google.colab.patches import cv2_imshow # colab-specific function

# %%
cv.__version__ # check version of OpenCV
# Out:
# '3.4.3'

# %% [markdown]
# ### Task 1

# %%
caps = cv.imread('caps.jpg')
res = cv.resize(caps,None,fx=2, fy=2, interpolation = cv.INTER_CUBIC)
#OR
#height, width = caps.shape[:2]
caps_scaled = cv.resize(caps,(600, 800), interpolation = cv.INTER_CUBIC) # only int
cv2_imshow(caps_scaled)
# Out:
# <PIL.Image.Image image mode=RGB size=600x800 at 0x7EFC955A4860>

# %%
caps = cv.imread('caps1.png')
hsv = cv.cvtColor(caps, cv.COLOR_BGR2HSV)

lower_blue = np.array([0,80,100])
upper_blue = np.array([100,250,250])

# Threshold the HSV image to get only blue colors
mask = cv.inRange(hsv, lower_blue, upper_blue)

# Bitwise-AND mask and original image
blue_cap = cv.bitwise_and(caps, caps, mask = mask)
cv2_imshow(caps)
cv2_imshow(mask)
cv2_imshow(blue_cap)
# Out:
# <PIL.Image.Image image mode=RGB size=600x800 at 0x7EFC93CADA90>
# <PIL.Image.Image image mode=L size=600x800 at 0x7EFC93CADA20>
# <PIL.Image.Image image mode=RGB size=600x800 at 0x7EFC93CADB70>

# %% [markdown]
# ### Task 2

# %%
import random as rng 

img = cv.imread("nobg_plastic.jpg")
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
img_blur = cv.blur(img_gray, (3,3))
img_blur = cv.resize(img_blur,None,fx=0.2, fy=0.2, interpolation = cv.INTER_CUBIC) # scaled down x0.2

cv2_imshow(img_blur)

low_threshold = 70 # pixel value 
ratio = 3

canny_output = cv.Canny(img_blur, low_threshold, low_threshold * ratio)
_, contours, _ = cv.findContours(canny_output, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
cv2_imshow(canny_output)

# Get the moments
mu = [None]*len(contours)
for i in range(len(contours)):
  mu[i] = cv.moments(contours[i])

# Get the mass centers
mc = [None]*len(contours)
for i in range(len(contours)):
  # add 1e-5 to avoid division by zero
  mc[i] = (mu[i]['m10'] / (mu[i]['m00'] + 1e-5), mu[i]['m01'] / (mu[i]['m00'] + 1e-5))


# Draw contours
drawing = np.zeros((canny_output.shape[0], canny_output.shape[1], 3), dtype=np.uint8)
    
for i in range(len(contours)):
  color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
  cv.drawContours(drawing, contours, i, color, 2)
  cv.circle(drawing, (int(mc[i][0]), int(mc[i][1])), 4, color, -1)
    
cv2_imshow(drawing)

# here we calc area for every contour found in the image
for i in range(len(contours)):
  print(' * Contour[%d] - Area (M_00) = %.2f - Area OpenCV: %.2f - Length: %.2f' % (i, mu[i]['m00'], cv.contourArea(contours[i]), cv.arcLength(contours[i], True)))
# Out:
# <PIL.Image.Image image mode=L size=691x922 at 0x7EFC93C73438>
# <PIL.Image.Image image mode=L size=691x922 at 0x7EFC93C73400>
# <PIL.Image.Image image mode=RGB size=691x922 at 0x7EFC93C57588>
#  * Contour[0] - Area (M_00) = 6.00 - Area OpenCV: 6.00 - Length: 96.43
#  * Contour[1] - Area (M_00) = 0.00 - Area OpenCV: 0.00 - Length: 0.00
#  * Contour[2] - Area (M_00) = 4.00 - Area OpenCV: 4.00 - Length: 238.23
#  * Contour[3] - Area (M_00) = 66.50 - Area OpenCV: 66.50 - Length: 495.77
#  * Contour[4] - Area (M_00) = 1.00 - Area OpenCV: 1.00 - Length: 13.66
#  * Contour[5] - Area (M_00) = 0.00 - Area OpenCV: 0.00 - Length: 4.00
#  * Contour[6] - Area (M_00) = 28199.00 - Area OpenCV: 28199.00 - Length: 725.78
#  * Contour[7] - Area (M_00) = 27996.50 - Area OpenCV: 27996.50 - Length: 718.36
#  * Contour[8] - Area (M_00) = 4.00 - Area OpenCV: 4.00 - Length: 31.80
#  * Contour[9] - Area (M_00) = 35.00 - Area OpenCV: 35.00 - Length: 28.97
#  * Contour[10] - Area (M_00) = 4.00 - Area OpenCV: 4.00 - Length: 7.66
#  * Contour[11] - Area (M_00) = 24.00 - Area OpenCV: 24.00 - Length: 22.97
#  * Contour[12] - Area (M_00) = 426.50 - Area OpenCV: 426.50 - Length: 1436.94
#  * Contour[13] - Area (M_00) = 110.50 - Area OpenCV: 110.50 - Length: 99.30
#  * Contour[14] - Area (M_00) = 20.50 - Area OpenCV: 20.50 - Length: 126.61
#  * Contour[15] - Area (M_00) = 33.00 - Area OpenCV: 33.00 - Length: 287.97
#  * Contour[16] - Area (M_00) = 34.00 - Area OpenCV: 34.00 - Length: 234.94
#  * Contour[17] - Area (M_00) = 8.00 - Area OpenCV: 8.00 - Length: 49.94
#  * Contour[18] - Area (M_00) = 14.00 - Area OpenCV: 14.00 - Length: 33.31
#  * Contour[19] - Area (M_00) = 10.00 - Area OpenCV: 10.00 - Length: 12.49
#  * Contour[20] - Area (M_00) = 6.00 - Area OpenCV: 6.00 - Length: 46.97
#  * Contour[21] - Area (M_00) = 22.00 - Area OpenCV: 22.00 - Length: 19.66
#  * Contour[22] - Area (M_00) = 16.50 - Area OpenCV: 16.50 - Length: 16.73
#  * Contour[23] - Area (M_00) = 44.50 - Area OpenCV: 44.50 - Length: 31.56
#  * Contour[24] - Area (M_00) = 38.50 - Area OpenCV: 38.50 - Length: 25.56
#  * Contour[25] - Area (M_00) = 56.50 - Area OpenCV: 56.50 - Length: 31.90
#  * Contour[26] - Area (M_00) = 54.00 - Area OpenCV: 54.00 - Length: 30.14
#  * Contour[27] - Area (M_00) = 40.00 - Area OpenCV: 40.00 - Length: 100.08
#  * Contour[28] - Area (M_00) = 29.50 - Area OpenCV: 29.50 - Length: 22.73
#  * Contour[29] - Area (M_00) = 0.50 - Area OpenCV: 0.50 - Length: 9.07
#  * Contour[30] - Area (M_00) = 5.50 - Area OpenCV: 5.50 - Length: 76.87
#  * Contour[31] - Area (M_00) = 3.50 - Area OpenCV: 3.50 - Length: 35.56
#  * Contour[32] - Area (M_00) = 27.00 - Area OpenCV: 27.00 - Length: 32.97
#  * Contour[33] - Area (M_00) = 21.50 - Area OpenCV: 21.50 - Length: 18.73
#  * Contour[34] - Area (M_00) = 4.50 - Area OpenCV: 4.50 - Length: 39.56
#  * Contour[35] - Area (M_00) = 241.50 - Area OpenCV: 241.50 - Length: 101.01
#  * Contour[36] - Area (M_00) = 227.50 - Area OpenCV: 227.50 - Length: 84.18
#  * Contour[37] - Area (M_00) = 33.00 - Area OpenCV: 33.00 - Length: 28.14
#  * Contour[38] - Area (M_00) = 27.50 - Area OpenCV: 27.50 - Length: 20.73
#  * Contour[39] - Area (M_00) = 43.00 - Area OpenCV: 43.00 - Length: 32.97
#  * Contour[40] - Area (M_00) = 38.00 - Area OpenCV: 38.00 - Length: 24.97
#  * Contour[41] - Area (M_00) = 58.50 - Area OpenCV: 58.50 - Length: 30.73
#  * Contour[42] - Area (M_00) = 51.50 - Area OpenCV: 51.50 - Length: 28.38
#  * Contour[43] - Area (M_00) = 46.00 - Area OpenCV: 46.00 - Length: 38.14
#  * Contour[44] - Area (M_00) = 42.00 - Area OpenCV: 42.00 - Length: 26.14
#  * Contour[45] - Area (M_00) = 13.00 - Area OpenCV: 13.00 - Length: 72.28
#  * Contour[46] - Area (M_00) = 4.00 - Area OpenCV: 4.00 - Length: 7.66
#  * Contour[47] - Area (M_00) = 264.00 - Area OpenCV: 264.00 - Length: 80.28
#  * Contour[48] - Area (M_00) = 259.50 - Area OpenCV: 259.50 - Length: 74.53
#  * Contour[49] - Area (M_00) = 29.00 - Area OpenCV: 29.00 - Length: 186.17
#  * Contour[50] - Area (M_00) = 5.50 - Area OpenCV: 5.50 - Length: 9.07
#  * Contour[51] - Area (M_00) = 7.00 - Area OpenCV: 7.00 - Length: 48.28
#  * Contour[52] - Area (M_00) = 24.00 - Area OpenCV: 24.00 - Length: 260.62
#  * Contour[53] - Area (M_00) = 2.00 - Area OpenCV: 2.00 - Length: 17.31
#  * Contour[54] - Area (M_00) = 166.50 - Area OpenCV: 166.50 - Length: 113.50
#  * Contour[55] - Area (M_00) = 149.00 - Area OpenCV: 149.00 - Length: 50.63
#  * Contour[56] - Area (M_00) = 3.00 - Area OpenCV: 3.00 - Length: 38.28
#  * Contour[57] - Area (M_00) = 3.00 - Area OpenCV: 3.00 - Length: 168.57
#  * Contour[58] - Area (M_00) = 189.00 - Area OpenCV: 189.00 - Length: 1454.79
#  * Contour[59] - Area (M_00) = 1.00 - Area OpenCV: 1.00 - Length: 14.49
#  * Contour[60] - Area (M_00) = 123.50 - Area OpenCV: 123.50 - Length: 2038.83
#  * Contour[61] - Area (M_00) = 3.50 - Area OpenCV: 3.50 - Length: 1848.25
#  * Contour[62] - Area (M_00) = 0.00 - Area OpenCV: 0.00 - Length: 1861.88
#  * Contour[63] - Area (M_00) = 7.00 - Area OpenCV: 7.00 - Length: 452.94

# %%
w = 1200
h = 1200

# save all contours
with open("allContours.svg", "w+") as f:
    f.write(f'<svg width="{w}" height="{h}" xmlns="http://www.w3.org/2000/svg">')

    for c in contours:
        f.write('<path d="M')
        for i in range(len(c)):
            x, y = c[i][0]
            f.write(f"{x} {y} ")
        f.write('" style="stroke:pink"/>')
    f.write("</svg>")
